# %%
# %load_ext watermark

# %%
import os
import subprocess

os.environ["POLARS_FORCE_NEW_STREAMING"] = "1"

from IPython.display import display, HTML
import numpy as np
import pandas as pd
import polars as pl
import seaborn as sns
from teeplot import teeplot as tp
from tqdm import tqdm

from pylib._calc_compsummary_stats import calc_compsummary_stats
from pylib._seed_global_rngs import seed_global_rngs
# Out:
# Covasim 3.1.6 (2024-01-28) — © 2020-2024 by IDM

# %%
# %watermark -diwmuv -iv
# Out:
# Last updated: 2026-02-22T02:00:35.884935+00:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 7.31.1
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.8.0-1044-azure
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
# teeplot: 1.4.2
# pandas : 2.2.3
# polars : 1.29.0
# numpy  : 2.1.2
# seaborn: 0.13.2
#
# Watermark: 2.4.3

# %%
teeplot_subdir = "2025-05-19-compscreen-uk-big-summary"
teeplot_subdir
# Out:
# '2025-05-19-compscreen-uk-big-summary'

# %%
seed_global_rngs(1)

# %% [markdown]
# ## Get Data

# %%
data_sources = {
    "uk-big": "https://osf.io/pgj7t/download",
    # "uk": "https://osf.io/mkjy5/download",
    # "multistrain": "https://osf.io/ywmpt/download",
    # "vanilla": "https://osf.io/r8skg/download",
    # "vanilla-big": "https://osf.io/j4795/download",
    # "vanilla-big-1.3x": "https://osf.io/cnp5z/download",
}
tmp_path = f"/tmp/{teeplot_subdir}.pqt"

# %%
results = []

for source_name, url in data_sources.items():
    print(f"Downloading {source_name} data from {url}")

    subprocess.run(
        [
            "wget",
            "--tries=5",
            "--show-progress",
            "--progress=bar:force",
            "-O",
            str(tmp_path),
            url,
        ],
        check=True,
    )
    print("done!")

    df = pl.scan_parquet(
        tmp_path,
        low_memory=True,
        retries=5,
    )

    unique_groups = (
        df.unique(
            [
                "trt_name",
                "trt_n_downsample",
                "trt_hsurf_bits",
                "replicate_uuid",
            ]
        )
        .select(
            pl.col("trt_name"),
            pl.col("trt_n_downsample"),
            pl.col("trt_hsurf_bits"),
            pl.col("replicate_uuid"),
        )
        .drop_nans()
        .drop_nulls()
        .collect(engine="streaming")
    )

    for (trt_name, trt_n_downsample, trt_hsurf_bits, replicate_uuid) in tqdm(
        [*unique_groups.iter_rows()],
    ):
        group = df.filter(
            (pl.col("trt_name") == trt_name)
            & (pl.col("trt_n_downsample") == trt_n_downsample)
            & (pl.col("trt_hsurf_bits") == trt_hsurf_bits)
            & (pl.col("replicate_uuid") == replicate_uuid)
        ).collect(engine="streaming")

        for y in (
            "defmut_norm_all-num_leaves",
            # "defmut_norm_ot_bin:week-num_leaves",
            # "defmut_norm_ot_bin:fortnight-num_leaves",
            "defmut_norm_ot_bin:month-num_leaves",
            # "defmut_norm_ot_bin:quarter-num_leaves",
            # "defmut_norm_ot_bin:year-num_leaves",
            # "defmut_norm_match:variant_flavor-num_leaves",
            "defmut_norm_all-clade_duration",
            # "defmut_norm_ot_bin:week-clade_duration",
            # "defmut_norm_ot_bin:fortnight-clade_duration",
            "defmut_norm_ot_bin:month-clade_duration",
            # "defmut_norm_ot_bin:quarter-clade_duration",
            # "defmut_norm_ot_bin:year-clade_duration",
            # "defmut_norm_match:variant_flavor-clade_duration",
        ):
            res = calc_compsummary_stats(
                group.to_pandas(),
                x="is_focal_defmut",
                y=y,
            )
            results.extend(
                {
                    "source_name": source_name,
                    "trt_name": trt_name,
                    "trt_n_downsample": trt_n_downsample,
                    "trt_hsurf_bits": trt_hsurf_bits,
                    "replicate_uuid": replicate_uuid,
                    "y": y,
                    **record,
                }
                for record in res
            )
# Out:
# Downloading uk-big data from https://osf.io/pgj7t/download
# --2026-02-22 02:00:36--  https://osf.io/pgj7t/download
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://osf.io/download/pgj7t [following]
# --2026-02-22 02:00:36--  https://osf.io/download/pgj7t
# Reusing existing connection to osf.io:443.
# HTTP request sent, awaiting response... 308 Permanent Redirect
# Location: https://osf.io/download/pgj7t/ [following]
# --2026-02-22 02:00:36--  https://osf.io/download/pgj7t/
# Reusing existing connection to osf.io:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://files.osf.io/v1/resources/37fv8/providers/osfstorage/682d5f8cc1a255a482f08030 [following]
# --2026-02-22 02:00:36--  https://files.osf.io/v1/resources/37fv8/providers/osfstorage/682d5f8cc1a255a482f08030
# Resolving files.osf.io (files.osf.io)... 35.186.214.196
# Connecting to files.osf.io (files.osf.io)|35.186.214.196|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/cos-osf-prod-files-us-east1/9df707861ab99590baf2b9903efccd064c15d70d2bcf704b5b082e4d7fd45d4c?response-content-disposition=attachment%3B%20filename%3D%22a%3Dresult%2Bdate%3D2025-05-21%2Bjob%3D2025-05-18-uk-run_compscreen-big%2Bext%3D.pqt%22%3B%20filename%2A%3DUTF-8%27%27a%253Dresult%252Bdate%253D2025-05-21%252Bjob%253D2025-05-18-uk-run_compscreen-big%252Bext%253D.pqt&GoogleAccessId=files-us%40cos-osf-prod.iam.gserviceaccount.com&Expires=1771725696&Signature=vjrguj1XC%2BRo6ZwicnUKeo%2BX%2B6JeBFRwRjtrf23UY5QCWTtrsIfcecDljmUD%2F2BIZxenTm3Xo9RJMjXAixfUZXHbIRxi5%2Br4fnu0HZa%2F1By6yZeLOozPTuUVGNJ2IsxxdMGE%2FpF4XwcQC9UyNulXky9TRR6DAgivwr0gGiH4TadyS3ORUj8kS0uH05z3ICw2TYhzJfdIEH7hwxyhfStAk0dpBLjVd7ef%2Bc10sdMnRliYk1eHTvIXo3JtWN8G9UdM%2Br4L3O7dsM5sFtopR5j4l%2B4DndXO8BXxLaFx%2BZEFu%2BJG4xmoEtwz9pOotYwo9xyqn740zGFlnlHcnOhd2a8scA%3D%3D [following]
# --2026-02-22 02:00:36--  https://storage.googleapis.com/cos-osf-prod-files-us-east1/9df707861ab99590baf2b9903efccd064c15d70d2bcf704b5b082e4d7fd45d4c?response-content-disposition=attachment%3B%20filename%3D%22a%3Dresult%2Bdate%3D2025-05-21%2Bjob%3D2025-05-18-uk-run_compscreen-big%2Bext%3D.pqt%22%3B%20filename%2A%3DUTF-8%27%27a%253Dresult%252Bdate%253D2025-05-21%252Bjob%253D2025-05-18-uk-run_compscreen-big%252Bext%253D.pqt&GoogleAccessId=files-us%40cos-osf-prod.iam.gserviceaccount.com&Expires=1771725696&Signature=vjrguj1XC%2BRo6ZwicnUKeo%2BX%2B6JeBFRwRjtrf23UY5QCWTtrsIfcecDljmUD%2F2BIZxenTm3Xo9RJMjXAixfUZXHbIRxi5%2Br4fnu0HZa%2F1By6yZeLOozPTuUVGNJ2IsxxdMGE%2FpF4XwcQC9UyNulXky9TRR6DAgivwr0gGiH4TadyS3ORUj8kS0uH05z3ICw2TYhzJfdIEH7hwxyhfStAk0dpBLjVd7ef%2Bc10sdMnRliYk1eHTvIXo3JtWN8G9UdM%2Br4L3O7dsM5sFtopR5j4l%2B4DndXO8BXxLaFx%2BZEFu%2BJG4xmoEtwz9pOotYwo9xyqn740zGFlnlHcnOhd2a8scA%3D%3D
# Resolving storage.googleapis.com (storage.googleapis.com)... 192.178.218.207, 142.250.31.207, 172.253.62.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|192.178.218.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 875499626 (835M) [application/octet-stream]
# Saving to: ‘/tmp/2025-05-19-compscreen-uk-big-summary.pqt’
#
# /tmp/2025-05-19-com 100%[===================>] 834.94M   187MB/s    in 5.4s
#
# 2026-02-22 02:00:42 (153 MB/s) - ‘/tmp/2025-05-19-compscreen-uk-big-summary.pqt’ saved [875499626/875499626]
# done!
# 100%|██████████| 70/70 [02:52<00:00,  2.46s/it]

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#     source_name           trt_name  trt_n_downsample  trt_hsurf_bits  \
# 0        uk-big  Sben1.1x/Gdel1.1x           1000000               0
# 1        uk-big  Sben1.1x/Gdel1.1x           1000000               0
# 2        uk-big  Sben1.1x/Gdel1.1x           1000000               0
# 3        uk-big  Sben1.1x/Gdel1.1x           1000000               0
# 4        uk-big  Sben1.1x/Gdel1.1x           1000000               0
# ..          ...                ...               ...             ...
# 835      uk-big      Sben2x/Gdel2x           1000000               0
# 836      uk-big      Sben2x/Gdel2x           1000000               0
# 837      uk-big      Sben2x/Gdel2x           1000000               0
# 838      uk-big      Sben2x/Gdel2x           1000000               0
# 839      uk-big      Sben2x/Gdel2x           1000000               0
#
#                            replicate_uuid  \
# 0    22ce47ac-0205-87ef-97f7-1e6e1a4ae8a3
# 1    22ce47ac-0205-87ef-97f7-1e6e1a4ae8a3
# 2    22ce47ac-0205-87ef-97f7-1e6e1a4ae8a3
# 3    22ce47ac-0205-87ef-97f7-1e6e1a4ae8a3
# 4    22ce47ac-0205-87ef-97f7-1e6e1a4ae8a3
# ..                                    ...
# 835  189548bb-82b1-8117-81d3-1b7eb187d2cc
# 836  189548bb-82b1-8117-81d3-1b7eb187d2cc
# 837  189548bb-82b1-8117-81d3-1b7eb187d2cc
# 838  189548bb-82b1-8117-81d3-1b7eb187d2cc
# 839  189548bb-82b1-8117-81d3-1b7eb187d2cc
#
#                                            y  label  binom_n  binom_k     n  \
# 0                 defmut_norm_all-num_leaves    all      480      314   480
# 1                 defmut_norm_all-num_leaves  False      472      307   480
# 2                 defmut_norm_all-num_leaves   True        8        7   480
# 3        defmut_norm_ot_bin:month-num_leaves    all      480      315   480
# 4        defmut_norm_ot_bin:month-num_leaves  False      472      308   480
# ..                                       ...    ...      ...      ...   ...
# 835           defmut_norm_all-clade_duration  False      492      314  1993
# 836           defmut_norm_all-clade_duration   True     1501     1110  1993
# 837  defmut_norm_ot_bin:month-clade_duration    all     1993     1422  1993
# 838  defmut_norm_ot_bin:month-clade_duration  False      492      314  1993
# 839  defmut_norm_ot_bin:month-clade_duration   True     1501     1108  1993
#
#      n_boot  p_boot   p_binom          p_mw      u_mw  cliffs_delta  na  n_grp
# 0     10000  0.4948  0.521093           NaN       NaN           NaN   0    480
# 1     10000  0.5671  0.588640  1.161836e-01    2282.5      0.208951   0    472
# 2     10000  0.0687  0.175368  8.844080e-01    1493.5     -0.208951   0      8
# 3     10000  0.5009  0.546304           NaN       NaN           NaN   0    480
# 4     10000  0.5694  0.612421  7.963706e-02    2427.5      0.285752   0    472
# ..      ...     ...       ...           ...       ...           ...  ..    ...
# 835   10000  1.0000  0.999898  1.168934e-08  418554.0      0.133537   0    492
# 836   10000  0.0023  0.016525  1.000000e+00  319938.0     -0.133537   0   1501
# 837   10000  0.4945  0.539477           NaN       NaN           NaN   0   1993
# 838   10000  1.0000  0.999892  6.592296e-06  416906.5      0.129075   0    492
# 839   10000  0.0064  0.020699  9.999934e-01  321585.5     -0.129075   0   1501
#
# [840 rows x 18 columns]

# %%
results_df[results_df["label"] == True].groupby(  # noqa: E712
    ["trt_name", "trt_n_downsample", "trt_hsurf_bits", "y"]
).agg(
    {"n_grp": ["mean", "std"]},
)
# Out:
#                                                                                             n_grp  \
#                                                                                              mean
# trt_name          trt_n_downsample trt_hsurf_bits y
# Sben1.1x/Gdel1.1x 1000000          0              defmut_norm_all-clade_duration              7.2
#                                                   defmut_norm_all-num_leaves                  7.2
#                                                   defmut_norm_ot_bin:month-clade_duration     7.2
#                                                   defmut_norm_ot_bin:month-num_leaves         7.2
#                                    64             defmut_norm_all-clade_duration              6.6
#                                                   defmut_norm_all-num_leaves                  6.6
#                                                   defmut_norm_ot_bin:month-clade_duration     6.6
#                                                   defmut_norm_ot_bin:month-num_leaves         6.6
# Sben1.1x/Gneu     1000000          0              defmut_norm_all-clade_duration              7.0
#                                                   defmut_norm_all-num_leaves                  7.0
#                                                   defmut_norm_ot_bin:month-clade_duration     7.0
#                                                   defmut_norm_ot_bin:month-num_leaves         7.0
#                                    64             defmut_norm_all-clade_duration              6.4
#                                                   defmut_norm_all-num_leaves                  6.4
#                                                   defmut_norm_ot_bin:month-clade_duration     6.4
#                                                   defmut_norm_ot_bin:month-num_leaves         6.4
# Sben1.3x/Gdel1.3x 1000000          0              defmut_norm_all-clade_duration             58.4
#                                                   defmut_norm_all-num_leaves                 58.4
#                                                   defmut_norm_ot_bin:month-clade_duration    58.4
#                                                   defmut_norm_ot_bin:month-num_leaves        58.4
#                                    64             defmut_norm_all-clade_duration             53.6
#                                                   defmut_norm_all-num_leaves                 53.6
#                                                   defmut_norm_ot_bin:month-clade_duration    53.6
#                                                   defmut_norm_ot_bin:month-num_leaves        53.6
# Sben1.3x/Gneu     1000000          0              defmut_norm_all-clade_duration             91.0
#                                                   defmut_norm_all-num_leaves                 91.0
#                                                   defmut_norm_ot_bin:month-clade_duration    91.0
#                                                   defmut_norm_ot_bin:month-num_leaves        91.0
#                                    64             defmut_norm_all-clade_duration             78.2
#                                                   defmut_norm_all-num_leaves                 78.2
#                                                   defmut_norm_ot_bin:month-clade_duration    78.2
#                                                   defmut_norm_ot_bin:month-num_leaves        78.2
# Sben2x/Gdel2x     1000000          0              defmut_norm_all-clade_duration           1419.2
#                                                   defmut_norm_all-num_leaves               1419.2
#                                                   defmut_norm_ot_bin:month-clade_duration  1419.2
#                                                   defmut_norm_ot_bin:month-num_leaves      1419.2
#                                    64             defmut_norm_all-clade_duration           1185.6
#                                                   defmut_norm_all-num_leaves               1185.6
#                                                   defmut_norm_ot_bin:month-clade_duration  1185.6
#                                                   defmut_norm_ot_bin:month-num_leaves      1185.6
# Sben2x/Gneu       1000000          0              defmut_norm_all-clade_duration           2569.2
#                                                   defmut_norm_all-num_leaves               2569.2
#                                                   defmut_norm_ot_bin:month-clade_duration  2569.2
#                                                   defmut_norm_ot_bin:month-num_leaves      2569.2
#                                    64             defmut_norm_all-clade_duration           2043.4
#                                                   defmut_norm_all-num_leaves               2043.4
#                                                   defmut_norm_ot_bin:month-clade_duration  2043.4
#                                                   defmut_norm_ot_bin:month-num_leaves      2043.4
# Sneu/Gneu         1000000          0              defmut_norm_all-clade_duration              5.4
#                                                   defmut_norm_all-num_leaves                  5.4
#                                                   defmut_norm_ot_bin:month-clade_duration     5.4
#                                                   defmut_norm_ot_bin:month-num_leaves         5.4
#                                    64             defmut_norm_all-clade_duration              5.8
#                                                   defmut_norm_all-num_leaves                  5.8
#                                                   defmut_norm_ot_bin:month-clade_duration     5.8
#                                                   defmut_norm_ot_bin:month-num_leaves         5.8
#
#
#                                                                                                  std
# trt_name          trt_n_downsample trt_hsurf_bits y
# Sben1.1x/Gdel1.1x 1000000          0              defmut_norm_all-clade_duration            3.114482
#                                                   defmut_norm_all-num_leaves                3.114482
#                                                   defmut_norm_ot_bin:month-clade_duration   3.114482
#                                                   defmut_norm_ot_bin:month-num_leaves       3.114482
#                                    64             defmut_norm_all-clade_duration            1.516575
#                                                   defmut_norm_all-num_leaves                1.516575
#                                                   defmut_norm_ot_bin:month-clade_duration   1.516575
#                                                   defmut_norm_ot_bin:month-num_leaves       1.516575
# Sben1.1x/Gneu     1000000          0              defmut_norm_all-clade_duration            2.236068
#                                                   defmut_norm_all-num_leaves                2.236068
#                                                   defmut_norm_ot_bin:month-clade_duration   2.236068
#                                                   defmut_norm_ot_bin:month-num_leaves       2.236068
#                                    64             defmut_norm_all-clade_duration            1.816590
#                                                   defmut_norm_all-num_leaves                1.816590
#                                                   defmut_norm_ot_bin:month-clade_duration   1.816590
#                                                   defmut_norm_ot_bin:month-num_leaves       1.816590
# Sben1.3x/Gdel1.3x 1000000          0              defmut_norm_all-clade_duration           14.135063
#                                                   defmut_norm_all-num_leaves               14.135063
#                                                   defmut_norm_ot_bin:month-clade_duration  14.135063
#                                                   defmut_norm_ot_bin:month-num_leaves      14.135063
#                                    64             defmut_norm_all-clade_duration           16.471187
#                                                   defmut_norm_all-num_leaves               16.471187
#                                                   defmut_norm_ot_bin:month-clade_duration  16.471187
#                                                   defmut_norm_ot_bin:month-num_leaves      16.471187
# Sben1.3x/Gneu     1000000          0              defmut_norm_all-clade_duration           17.958285
#                                                   defmut_norm_all-num_leaves               17.958285
#                                                   defmut_norm_ot_bin:month-clade_duration  17.958285
#                                                   defmut_norm_ot_bin:month-num_leaves      17.958285
#                                    64             defmut_norm_all-clade_duration            9.364828
#                                                   defmut_norm_all-num_leaves                9.364828
#                                                   defmut_norm_ot_bin:month-clade_duration   9.364828
#                                                   defmut_norm_ot_bin:month-num_leaves       9.364828
# Sben2x/Gdel2x     1000000          0              defmut_norm_all-clade_duration           78.693710
#                                                   defmut_norm_all-num_leaves               78.693710
#                                                   defmut_norm_ot_bin:month-clade_duration  78.693710
#                                                   defmut_norm_ot_bin:month-num_leaves      78.693710
#                                    64             defmut_norm_all-clade_duration           55.572475
#                                                   defmut_norm_all-num_leaves               55.572475
#                                                   defmut_norm_ot_bin:month-clade_duration  55.572475
#                                                   defmut_norm_ot_bin:month-num_leaves      55.572475
# Sben2x/Gneu       1000000          0              defmut_norm_all-clade_duration           43.905581
#                                                   defmut_norm_all-num_leaves               43.905581
#                                                   defmut_norm_ot_bin:month-clade_duration  43.905581
#                                                   defmut_norm_ot_bin:month-num_leaves      43.905581
#                                    64             defmut_norm_all-clade_duration           79.970620
#                                                   defmut_norm_all-num_leaves               79.970620
#                                                   defmut_norm_ot_bin:month-clade_duration  79.970620
#                                                   defmut_norm_ot_bin:month-num_leaves      79.970620
# Sneu/Gneu         1000000          0              defmut_norm_all-clade_duration            3.974921
#                                                   defmut_norm_all-num_leaves                3.974921
#                                                   defmut_norm_ot_bin:month-clade_duration   3.974921
#                                                   defmut_norm_ot_bin:month-num_leaves       3.974921
#                                    64             defmut_norm_all-clade_duration            3.033150
#                                                   defmut_norm_all-num_leaves                3.033150
#                                                   defmut_norm_ot_bin:month-clade_duration   3.033150
#                                                   defmut_norm_ot_bin:month-num_leaves       3.033150

# %%
results_df["y"] = results_df["y"].str.removeprefix("defmut_norm_all-")
results_df["y"] = results_df["y"].str.removeprefix("defmut_norm_ot_bin:")
results_df["y"] = results_df["y"].str.removeprefix("defmut_norm_match:")
results_df["y"] = results_df["y"].str.replace("-", "\n")
results_df["y"] = results_df["y"].str.replace("_", " ")

results_df["label"] = results_df["label"].astype(str)
results_df["label"] = results_df["label"].str.replace("False", "bkgnd")
results_df["label"] = results_df["label"].str.replace("True", "focal")

results_df["trt_name_"] = results_df["trt_name"].str.replace("/", "\n")

# %%
bins = [-np.inf, 0.001, 0.01, 0.05, np.inf]
labels = ["<0.001", "<0.01", "<0.05", "ns"]
gentle_palette = ["#4361EE", "#7209B7", "#F72585", "#A9A9A9"]

for y in "p_boot", "p_binom", "p_mw":
    display(HTML(f"<h1>{y=}</h1>"))

    data = results_df[
        (results_df["trt_hsurf_bits"] == 0)
        & (
            results_df["trt_n_downsample"]
            == results_df["trt_n_downsample"].max()
        )
        & (results_df["label"] != "all")
    ].copy()
    data["sig"] = pd.cut(
        data[y],
        bins=bins,
        labels=labels,
        include_lowest=True,
    )
    data["sig"] = data["sig"].cat.set_categories(labels, ordered=True)
    data["smallsamp"] = data["n_grp"] < 30
    data["smallsamp"] = data["smallsamp"].map({True: "<30", False: "ok"})
    data["y_"] = (
        data["y"]
        .str.replace("month\n", "")
        .str.replace("num leaves", "clade\nsize")
        .str.replace("clade duration", "clade\nduration")
    )
    col_order = filter(
        set(data["trt_name_"]).__contains__,
        [
            "Sneu\nGneu",
            "Sben1.1x\nGneu",
            "Sben1.3x\nGneu",
            "Sben2x\nGneu",
            "Sben1.1x\nGdel1.1x",
            "Sben1.3x\nGdel1.3x",
            "Sben2x\nGdel2x",
        ],
    )
    col_order = [*col_order]
    with tp.teed(
        sns.catplot,
        data=data[
            data["y"].str.startswith("month").values
            & (data["label"] == "focal")
        ],
        y=y,
        col="trt_name_",
        row="y_",
        hue="sig",
        x="smallsamp",
        col_order=col_order,
        legend=False,
        kind="swarm",
        margin_titles=True,
        height=1.4,
        aspect=0.9,
        size=4,
        palette=gentle_palette,
        teeplot_outattrs={"comparator": "month"},
        teeplot_subdir=teeplot_subdir,
    ) as teed:

        teed.set_titles(col_template="{col_name}", row_template="{row_name}")
        for ax in teed.axes.flat:
            ax.set_yscale("symlog", linthresh=0.0001)
            ax.set_ylim(-0.0001, None)
            ax.axhline(
                0.05,
                alpha=0.4,
                color=gentle_palette[2],
                linestyle="--",
                linewidth=2,
            )
            ax.axhline(
                0.01,
                alpha=0.4,
                color=gentle_palette[1],
                linestyle="--",
                linewidth=2,
            )
            ax.axhline(
                0.001,
                alpha=0.4,
                color=gentle_palette[0],
                linestyle="--",
                linewidth=2,
            )
            ax.tick_params(axis="x", rotation=-60)
            ax.set_xlabel("")
            ax.set_ylabel(y.replace("_", " "))

        teed.tight_layout()
# Out:
# <h1>y='p_boot'</h1>
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=y+viz=catplot+x=smallsamp+y=p-boot+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=y+viz=catplot+x=smallsamp+y=p-boot+ext=.png
# <h1>y='p_binom'</h1>
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=y+viz=catplot+x=smallsamp+y=p-binom+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=y+viz=catplot+x=smallsamp+y=p-binom+ext=.png
# <h1>y='p_mw'</h1>
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=y+viz=catplot+x=smallsamp+y=p-mw+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=y+viz=catplot+x=smallsamp+y=p-mw+ext=.png

# %%
bins = [-np.inf, 0.001, 0.01, 0.05, np.inf]
labels = ["<0.001", "<0.01", "<0.05", "ns"]
gentle_palette = ["#4361EE", "#7209B7", "#F72585", "#A9A9A9"]

for y in "p_boot", "p_binom", "p_mw", "u_mw", "cliffs_delta":
    display(HTML(f"<h1>{y=}</h1>"))

    data = results_df[
        (results_df["trt_hsurf_bits"] == 0)
        & (
            results_df["trt_n_downsample"]
            == results_df["trt_n_downsample"].max()
        )
        & (results_df["label"] != "all")
    ].copy()
    data["sig"] = pd.cut(
        data[y],
        bins=bins,
        labels=labels,
        include_lowest=True,
    )
    data["sig"] = data["sig"].cat.set_categories(labels, ordered=True)
    col_order = filter(
        set(data["trt_name_"]).__contains__,
        [
            "Sneu\nGneu",
            "Sben1.1x\nGneu",
            "Sben1.3x\nGneu",
            "Sben2x\nGneu",
            "Sben1.1x\nGdel1.1x",
            "Sben1.3x\nGdel1.3x",
            "Sben2x\nGdel2x",
        ],
    )
    col_order = [*col_order]
    with tp.teed(
        sns.catplot,
        data=data,
        y=y,
        x="y",
        col="trt_name_",
        row="label",
        hue="sig",
        col_order=col_order,
        legend=False,
        kind="swarm",
        margin_titles=True,
        height=2,
        aspect=1.2,
        palette=gentle_palette,
        size=4,
        teeplot_subdir=teeplot_subdir,
    ) as teed:
        teed.set_titles(col_template="{col_name}", row_template="{row_name}")
        for ax in teed.axes.flat:
            ax.set_yscale("symlog", linthresh=0.0001)
            ax.set_ylim(-0.0001, None)
            ax.axhline(
                0.05,
                alpha=0.4,
                color=gentle_palette[2],
                linestyle="--",
                linewidth=2,
            )
            ax.axhline(
                0.01,
                alpha=0.4,
                color=gentle_palette[1],
                linestyle="--",
                linewidth=2,
            )
            ax.axhline(
                0.001,
                alpha=0.4,
                color=gentle_palette[0],
                linestyle="--",
                linewidth=2,
            )
            ax.tick_params(axis="x", rotation=-60)
            ax.set_xlabel("")
            ax.set_ylabel(y.replace("_", " "))

        teed.tight_layout()

    with tp.teed(
        sns.catplot,
        data=data[data["y"].str.startswith("month").values],
        y=y,
        x="y",
        col="trt_name_",
        row="label",
        hue="sig",
        col_order=col_order,
        legend=False,
        kind="swarm",
        margin_titles=True,
        height=1.8,
        aspect=0.8,
        size=4,
        palette=gentle_palette,
        teeplot_outattrs={"comparator": "month"},
        teeplot_subdir=teeplot_subdir,
    ) as teed:
        teed.set_titles(col_template="{col_name}", row_template="{row_name}")
        for ax in teed.axes.flat:
            ax.set_yscale("symlog", linthresh=0.0001)
            ax.set_ylim(-0.0001, None)
            ax.axhline(
                0.05,
                alpha=0.4,
                color=gentle_palette[2],
                linestyle="--",
                linewidth=2,
            )
            ax.axhline(
                0.01,
                alpha=0.4,
                color=gentle_palette[1],
                linestyle="--",
                linewidth=2,
            )
            ax.axhline(
                0.001,
                alpha=0.4,
                color=gentle_palette[0],
                linestyle="--",
                linewidth=2,
            )
            ax.tick_params(axis="x", rotation=-60)
            ax.set_xlabel("")
            ax.set_ylabel(y.replace("_", " "))

        teed.tight_layout()
# Out:
# <h1>y='p_boot'</h1>
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-boot+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-boot+ext=.png
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-boot+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-boot+ext=.png
# <h1>y='p_binom'</h1>
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-binom+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-binom+ext=.png
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-binom+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-binom+ext=.png
# <h1>y='p_mw'</h1>
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-mw+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-mw+ext=.png
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-mw+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=p-mw+ext=.png
# <h1>y='u_mw'</h1>
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=u-mw+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=u-mw+ext=.png
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=u-mw+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=u-mw+ext=.png
# <h1>y='cliffs_delta'</h1>
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=cliffs-delta+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=cliffs-delta+ext=.png
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=cliffs-delta+ext=.pdf
# teeplots/2025-05-19-compscreen-uk-big-summary/col=trt-name+comparator=month+hue=sig+kind=swarm+row=label+viz=catplot+x=y+y=cliffs-delta+ext=.png
