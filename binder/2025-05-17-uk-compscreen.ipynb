# %%
# %load_ext watermark

# %%
import logging

from IPython.display import display, HTML
from matplotlib import pyplot as plt
import pandas as pd
from retry import retry
from slugify import slugify
from teeplot import teeplot as tp

from pylib._percentilestatcat_plot import (
    percentilestatcat_plot,
)
from pylib._seed_global_rngs import seed_global_rngs
# Out:
# Covasim 3.1.6 (2024-01-28) — © 2020-2024 by IDM

# %%
# %watermark -diwmuv -iv
# Out:
# Last updated: 2025-05-18T15:40:49.036619+00:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 7.31.1
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.8.0-1027-azure
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
# pandas    : 2.2.3
# logging   : 0.5.1.2
# matplotlib: 3.9.2
# teeplot   : 1.4.2
#
# Watermark: 2.4.3

# %%
teeplot_subdir = "2025-05-17-uk-compscreen"
teeplot_subdir
# Out:
# '2025-05-17-uk-compscreen'

# %%
seed_global_rngs(1)

# %% [markdown]
# ## Get Data

# %%
df = retry(tries=5, logger=logging.getLogger(__name__))(pd.read_parquet)(
    "https://osf.io/y95d6/download",
)

df.head()
# Out:
#      source    target  date        layer    variant sequence_focal  \
# 0  153575.0  153575.0   0.0  importation  Wildtype+              +
# 1  150915.0  150915.0   0.0  importation  Wildtype+              +
# 2  150969.0  150969.0   0.0  importation  Wildtype+              +
# 3  151167.0  151167.0   0.0  importation  Wildtype+              +
# 4  151911.0  151911.0   0.0  importation  Wildtype+              +
#
#                                  sequence_background  id  ancestor_id  \
# 0  +++++++++++++++++++++++++++++++++++++++++++++++++   0            0
# 1  +++++++++++++++++++++++++++++++++++++++++++++++++   1            0
# 2  +++++++++++++++++++++++++++++++++++++++++++++++++   2            0
# 3  +++++++++++++++++++++++++++++++++++++++++++++++++   3            0
# 4  +++++++++++++++++++++++++++++++++++++++++++++++++   4            0
#
#    origin_time  ... is_leaf  left_child_id right_child_id is_left_child  \
# 0            0  ...    None            NaN            NaN          None
# 1            0  ...    None            NaN            NaN          None
# 2            0  ...    None            NaN            NaN          None
# 3            0  ...    None            NaN            NaN          None
# 4            0  ...    None            NaN            NaN          None
#
#   is_right_child  sister_id  alifestd_calc_trait_count_asexual  \
# 0           None        NaN                                NaN
# 1           None        NaN                                NaN
# 2           None        NaN                                NaN
# 3           None        NaN                                NaN
# 4           None        NaN                                NaN
#
#    alifestd_screen_trait_defined_clades_fisher_asexual_absent  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    alifestd_screen_trait_defined_clades_fisher_asexual_present  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   alifestd_screen_trait_defined_clades_naive_asexual
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 143 columns]

# %% [markdown]
# ## Plot Data

# %%
for trt_name, group in df.groupby("trt_name", observed=True):
    display(HTML(f"<h1>{trt_name}</h1>"))

    dfx = group[
        (group["replicate_uuid"] == group["replicate_uuid"].unique()[0])
    ].reset_index(drop=True)

    dfx_ = dfx.copy()
    dfx_["is_focal_defmut"] = "null"
    data = pd.concat([dfx, dfx_], ignore_index=True)

    for y in (
        "defmut_norm_all-num_leaves",
        # "defmut_norm_ot_delta:4-num_leaves",
        # "defmut_norm_ot_delta:7-num_leaves",
        "defmut_norm_ot_delta:14-num_leaves",
        # "defmut_norm_ot_delta:28-num_leaves",
        # "defmut_norm_ot_delta:44-num_leaves",
        "defmut_norm_match:variant_flavor-num_leaves",
        "defmut_norm_all-clade_duration",
        # "defmut_norm_ot_delta:4-clade_duration",
        # "defmut_norm_ot_delta:7-clade_duration",
        "defmut_norm_ot_delta:14-clade_duration",
        # "defmut_norm_ot_delta:28-clade_duration",
        # "defmut_norm_ot_delta:44-clade_duration",
        "defmut_norm_match:variant_flavor-clade_duration",
    ):
        display(HTML(f"<h2>{trt_name} {y}</h2>"))
        plt.close("all")  # release resources
        with tp.teed(
            percentilestatcat_plot,
            data=data,
            x="is_focal_defmut",
            y=y,
            hue="is_focal_defmut",
            teeplot_outattrs={
                "trt_name": slugify(trt_name),
            },
            teeplot_subdir=teeplot_subdir,
        ):
            pass
# Out:
# <h1>Sben2x/Gneu</h1>
# <h2>Sben2x/Gneu defmut_norm_all-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.png
# <h2>Sben2x/Gneu defmut_norm_ot_delta:14-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.png
# <h2>Sben2x/Gneu defmut_norm_match:variant_flavor-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.png
# <h2>Sben2x/Gneu defmut_norm_all-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.png
# <h2>Sben2x/Gneu defmut_norm_ot_delta:14-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.png
# <h2>Sben2x/Gneu defmut_norm_match:variant_flavor-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.png
# <h1>Sneu/Gneu</h1>
# <h2>Sneu/Gneu defmut_norm_all-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.png
# <h2>Sneu/Gneu defmut_norm_ot_delta:14-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.png
# <h2>Sneu/Gneu defmut_norm_match:variant_flavor-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.png
# <h2>Sneu/Gneu defmut_norm_all-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.png
# <h2>Sneu/Gneu defmut_norm_ot_delta:14-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.png
# <h2>Sneu/Gneu defmut_norm_match:variant_flavor-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sneu-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.png
# <h1>Sben1.3x/Gdel1.3x</h1>
# <h2>Sben1.3x/Gdel1.3x defmut_norm_all-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.png
# <h2>Sben1.3x/Gdel1.3x defmut_norm_ot_delta:14-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.png
# <h2>Sben1.3x/Gdel1.3x defmut_norm_match:variant_flavor-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.png
# <h2>Sben1.3x/Gdel1.3x defmut_norm_all-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.png
# <h2>Sben1.3x/Gdel1.3x defmut_norm_ot_delta:14-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.png
# <h2>Sben1.3x/Gdel1.3x defmut_norm_match:variant_flavor-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gdel1-3x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.png
# <h1>Sben1.1x/Gneu</h1>
# <h2>Sben1.1x/Gneu defmut_norm_all-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu defmut_norm_ot_delta:14-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu defmut_norm_match:variant_flavor-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu defmut_norm_all-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.png
# <h2>Sben1.1x/Gneu defmut_norm_ot_delta:14-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.png
# <h2>Sben1.1x/Gneu defmut_norm_match:variant_flavor-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.png
# <h1>Sben1.1x/Gdel1.1x</h1>
# <h2>Sben1.1x/Gdel1.1x defmut_norm_all-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x defmut_norm_ot_delta:14-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x defmut_norm_match:variant_flavor-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x defmut_norm_all-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.png
# <h2>Sben1.1x/Gdel1.1x defmut_norm_ot_delta:14-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.png
# <h2>Sben1.1x/Gdel1.1x defmut_norm_match:variant_flavor-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.png
# <h1>Sben1.3x/Gneu</h1>
# <h2>Sben1.3x/Gneu defmut_norm_all-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.png
# <h2>Sben1.3x/Gneu defmut_norm_ot_delta:14-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.png
# <h2>Sben1.3x/Gneu defmut_norm_match:variant_flavor-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.png
# <h2>Sben1.3x/Gneu defmut_norm_all-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.png
# <h2>Sben1.3x/Gneu defmut_norm_ot_delta:14-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.png
# <h2>Sben1.3x/Gneu defmut_norm_match:variant_flavor-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben1-3x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.png
# <h1>Sben2x/Gdel2x</h1>
# <h2>Sben2x/Gdel2x defmut_norm_all-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.png
# <h2>Sben2x/Gdel2x defmut_norm_ot_delta:14-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-num-leaves+ext=.png
# <h2>Sben2x/Gdel2x defmut_norm_match:variant_flavor-num_leaves</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-num-leaves+ext=.png
# <h2>Sben2x/Gdel2x defmut_norm_all-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.png
# <h2>Sben2x/Gdel2x defmut_norm_ot_delta:14-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-delta-14-clade-duration+ext=.png
# <h2>Sben2x/Gdel2x defmut_norm_match:variant_flavor-clade_duration</h2>
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.pdf
# teeplots/2025-05-17-uk-compscreen/hue=is-focal-defmut+trt_name=sben2x-gdel2x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-match-variant-flavor-clade-duration+ext=.png
