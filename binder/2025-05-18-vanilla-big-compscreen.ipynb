# %%
# %load_ext watermark

# %%
import urllib

from IPython.display import display, HTML
from matplotlib import pyplot as plt
import pandas as pd
import polars as pl
import seaborn as sns
from slugify import slugify
from teeplot import teeplot as tp

from pylib._percentilestatcat_plot import (
    percentilestatcat_plot,
)
from pylib._seed_global_rngs import seed_global_rngs
# Out:
# Covasim 3.1.6 (2024-01-28) — © 2020-2024 by IDM

# %%
# %watermark -diwmuv -iv
# Out:
# Last updated: 2025-05-20T14:10:20.971285+00:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 7.31.1
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.8.0-1027-azure
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
# seaborn   : 0.13.2
# matplotlib: 3.9.2
# pandas    : 2.2.3
# polars    : 1.29.0
# teeplot   : 1.4.2
#
# Watermark: 2.4.3

# %%
teeplot_subdir = "2025-05-18-vanilla-compscreen-big"
teeplot_subdir
# Out:
# '2025-05-18-vanilla-compscreen-big'

# %%
seed_global_rngs(1)

# %% [markdown]
# ## Get Data

# %%
url = "https://osf.io/ry5nd/download"
tmp_path = f"/tmp/{teeplot_subdir}.pqt"

print(f"Downloading data from {url}")

urllib.request.urlretrieve(url, tmp_path)
print("done!")
# Out:
# Downloading data from https://osf.io/ry5nd/download
# done!

# %%
df = pl.scan_parquet(
    tmp_path,
    low_memory=True,
    retries=5,
)
schema = df.collect_schema()

# %%
fil = (
    df.filter(
        pl.col("trt_hsurf_bits").eq(0),
        pl.col("trt_n_downsample").eq(pl.col("trt_n_downsample").max()),
    )
    .filter(
        pl.col("replicate_uuid").eq(
            pl.col("replicate_uuid").first().over("trt_name"),
        )
    )
    .select(
        pl.exclude([k for k, v in schema.items() if v == pl.String]),
    )
    .collect()
)

# %% [markdown]
# ## Plot Data

# %%
for (trt_name,), group in fil.group_by("trt_name"):
    display(HTML(f"<h1>{trt_name}</h1>"))

    dfx = group.to_pandas()
    dfx_ = group.to_pandas()
    dfx_["is_focal_defmut"] = "null"
    data = pd.concat([dfx, dfx_], ignore_index=True)

    for y in (
        "defmut_norm_all-num_leaves",
        # "defmut_norm_ot_bin:week-num_leaves",
        # "defmut_norm_ot_bin:fortnight-num_leaves",
        "defmut_norm_ot_bin:month-num_leaves",
        "defmut_norm_ot_bin:quarter-num_leaves",
        # "defmut_norm_ot_bin:year-num_leaves",
        # "defmut_norm_match:variant_flavor-num_leaves",
        "defmut_norm_all-clade_duration",
        # "defmut_norm_ot_bin:week-clade_duration",
        # "defmut_norm_ot_bin:fortnight-clade_duration",
        "defmut_norm_ot_bin:month-clade_duration",
        "defmut_norm_ot_bin:quarter-clade_duration",
        # "defmut_norm_ot_bin:year-clade_duration",
        # "defmut_norm_match:variant_flavor-clade_duration",
    ):
        display(HTML(f"<h2>{trt_name} {y}</h2>"))
        plt.close("all")  # release resources
        with tp.teed(
            percentilestatcat_plot,
            data=data,
            x="is_focal_defmut",
            y=y,
            hue="is_focal_defmut",
            teeplot_outattrs={
                "trt_name": slugify(trt_name),
            },
            teeplot_subdir=teeplot_subdir,
        ):
            pass
# Out:
# <h1>Sben1.1x/Gneu</h1>
# <h2>Sben1.1x/Gneu defmut_norm_all-num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu defmut_norm_ot_bin:month-num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-month-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-month-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu defmut_norm_ot_bin:quarter-num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-quarter-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-quarter-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu defmut_norm_all-clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.png
# <h2>Sben1.1x/Gneu defmut_norm_ot_bin:month-clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-month-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-month-clade-duration+ext=.png
# <h2>Sben1.1x/Gneu defmut_norm_ot_bin:quarter-clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-quarter-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gneu+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-quarter-clade-duration+ext=.png
# <h1>Sben1.1x/Gdel1.1x</h1>
# <h2>Sben1.1x/Gdel1.1x defmut_norm_all-num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x defmut_norm_ot_bin:month-num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-month-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-month-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x defmut_norm_ot_bin:quarter-num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-quarter-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-quarter-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x defmut_norm_all-clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-all-clade-duration+ext=.png
# <h2>Sben1.1x/Gdel1.1x defmut_norm_ot_bin:month-clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-month-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-month-clade-duration+ext=.png
# <h2>Sben1.1x/Gdel1.1x defmut_norm_ot_bin:quarter-clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-quarter-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=is-focal-defmut+trt_name=sben1-1x-gdel1-1x+viz=percentilestatcat-plot+x=is-focal-defmut+y=defmut-norm-ot-bin-quarter-clade-duration+ext=.png

# %%
for (trt_name,), group in fil.group_by("trt_name"):
    display(HTML(f"<h1>{trt_name}</h1>"))

    for norm in (
        "all",
        "match:variant_flavor",
        "ot_bin:week",
        "ot_bin:fortnight",
        "ot_bin:month",
        "ot_bin:quarter",
        "ot_bin:year",
    ):

        for var in "num_leaves", "clade_duration":
            display(HTML(f"<h2>{trt_name} {norm} {var}</h2>"))

            plt.close("all")  # release resources
            with tp.teed(
                sns.scatterplot,
                data=group,
                y=f"defmut_norm_{norm}-{var}",
                x=var,
                hue={
                    "all": None,
                    "ot_bin": "origin_time",
                    "match": "variant_flavor",
                }[norm.split(":")[0]],
                teeplot_outattrs={
                    "trt_name": slugify(trt_name),
                },
                teeplot_subdir=teeplot_subdir,
            ) as teed:
                teed.set_xscale(
                    {
                        "num_leaves": "log",
                        "clade_duration": "symlog",
                    }[var],
                )
                teed.set_ylim(-5, 105)
                teed.set_xlim(
                    {
                        "num_leaves": None,
                        "clade_duration": -0.5,
                    }[var],
                    None,
                )
                teed.spines[["right", "top"]].set_visible(False)
# Out:
# <h1>Sben1.1x/Gneu</h1>
# <h2>Sben1.1x/Gneu all num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-all-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-all-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu all clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-all-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-all-clade-duration+ext=.png
# <h2>Sben1.1x/Gneu match:variant_flavor num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=variant-flavor+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-match-variant-flavor-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=variant-flavor+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-match-variant-flavor-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu match:variant_flavor clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=variant-flavor+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-match-variant-flavor-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=variant-flavor+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-match-variant-flavor-clade-duration+ext=.png
# <h2>Sben1.1x/Gneu ot_bin:week num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-week-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-week-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu ot_bin:week clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-week-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-week-clade-duration+ext=.png
# <h2>Sben1.1x/Gneu ot_bin:fortnight num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-fortnight-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-fortnight-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu ot_bin:fortnight clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-fortnight-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-fortnight-clade-duration+ext=.png
# <h2>Sben1.1x/Gneu ot_bin:month num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-month-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-month-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu ot_bin:month clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-month-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-month-clade-duration+ext=.png
# <h2>Sben1.1x/Gneu ot_bin:quarter num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-quarter-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-quarter-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu ot_bin:quarter clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-quarter-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-quarter-clade-duration+ext=.png
# <h2>Sben1.1x/Gneu ot_bin:year num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-year-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-year-num-leaves+ext=.png
# <h2>Sben1.1x/Gneu ot_bin:year clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-year-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gneu+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-year-clade-duration+ext=.png
# <h1>Sben1.1x/Gdel1.1x</h1>
# <h2>Sben1.1x/Gdel1.1x all num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-all-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-all-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x all clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-all-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-all-clade-duration+ext=.png
# <h2>Sben1.1x/Gdel1.1x match:variant_flavor num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=variant-flavor+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-match-variant-flavor-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=variant-flavor+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-match-variant-flavor-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x match:variant_flavor clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=variant-flavor+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-match-variant-flavor-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=variant-flavor+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-match-variant-flavor-clade-duration+ext=.png
# <h2>Sben1.1x/Gdel1.1x ot_bin:week num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-week-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-week-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x ot_bin:week clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-week-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-week-clade-duration+ext=.png
# <h2>Sben1.1x/Gdel1.1x ot_bin:fortnight num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-fortnight-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-fortnight-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x ot_bin:fortnight clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-fortnight-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-fortnight-clade-duration+ext=.png
# <h2>Sben1.1x/Gdel1.1x ot_bin:month num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-month-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-month-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x ot_bin:month clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-month-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-month-clade-duration+ext=.png
# <h2>Sben1.1x/Gdel1.1x ot_bin:quarter num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-quarter-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-quarter-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x ot_bin:quarter clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-quarter-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-quarter-clade-duration+ext=.png
# <h2>Sben1.1x/Gdel1.1x ot_bin:year num_leaves</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-year-num-leaves+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=num-leaves+y=defmut-norm-ot-bin-year-num-leaves+ext=.png
# <h2>Sben1.1x/Gdel1.1x ot_bin:year clade_duration</h2>
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-year-clade-duration+ext=.pdf
# teeplots/2025-05-18-vanilla-compscreen-big/hue=origin-time+trt_name=sben1-1x-gdel1-1x+viz=scatterplot+x=clade-duration+y=defmut-norm-ot-bin-year-clade-duration+ext=.png
